# %%
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target
names = iris.target_names

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1, stratify=y
)

# KNN model
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

# Predict
y_pred = knn.predict(X_test)

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))

print("\n--- Detailed Predictions ---")
for i in range(len(y_test)):
    true_label = names[y_test[i]]
    pred_label = names[y_pred[i]]
    if true_label == pred_label:
        print(f"{i}: TRUE = {true_label} | PRED = {pred_label}  --> CORRECT")
    else:
        print(f"{i}: TRUE = {true_label} | PRED = {pred_label}  --> WRONG")
# Out:
# Accuracy: 0.9777777777777777
#
# --- Detailed Predictions ---
# 0: TRUE = virginica | PRED = virginica  --> CORRECT
# 1: TRUE = setosa | PRED = setosa  --> CORRECT
# 2: TRUE = setosa | PRED = setosa  --> CORRECT
# 3: TRUE = virginica | PRED = versicolor  --> WRONG
# 4: TRUE = versicolor | PRED = versicolor  --> CORRECT
# 5: TRUE = versicolor | PRED = versicolor  --> CORRECT
# 6: TRUE = virginica | PRED = virginica  --> CORRECT
# 7: TRUE = versicolor | PRED = versicolor  --> CORRECT
# 8: TRUE = virginica | PRED = virginica  --> CORRECT
# 9: TRUE = setosa | PRED = setosa  --> CORRECT
# 10: TRUE = setosa | PRED = setosa  --> CORRECT
# 11: TRUE = virginica | PRED = virginica  --> CORRECT
# 12: TRUE = setosa | PRED = setosa  --> CORRECT
# 13: TRUE = versicolor | PRED = versicolor  --> CORRECT
# 14: TRUE = setosa | PRED = setosa  --> CORRECT
# 15: TRUE = versicolor | PRED = versicolor  --> CORRECT
# 16: TRUE = virginica | PRED = virginica  --> CORRECT
# 17: TRUE = versicolor | PRED = versicolor  --> CORRECT
# 18: TRUE = versicolor | PRED = versicolor  --> CORRECT
# 19: TRUE = virginica | PRED = virginica  --> CORRECT
# 20: TRUE = virginica | PRED = virginica  --> CORRECT
# 21: TRUE = setosa | PRED = setosa  --> CORRECT
# 22: TRUE = versicolor | PRED = versicolor  --> CORRECT
# 23: TRUE = virginica | PRED = virginica  --> CORRECT
# 24: TRUE = versicolor | PRED = versicolor  --> CORRECT
# 25: TRUE = versicolor | PRED = versicolor  --> CORRECT
# 26: TRUE = versicolor | PRED = versicolor  --> CORRECT
# 27: TRUE = virginica | PRED = virginica  --> CORRECT
# 28: TRUE = setosa | PRED = setosa  --> CORRECT
# 29: TRUE = virginica | PRED = virginica  --> CORRECT
# 30: TRUE = setosa | PRED = setosa  --> CORRECT
# 31: TRUE = setosa | PRED = setosa  --> CORRECT
# 32: TRUE = versicolor | PRED = versicolor  --> CORRECT
# 33: TRUE = versicolor | PRED = versicolor  --> CORRECT
# 34: TRUE = virginica | PRED = virginica  --> CORRECT
# 35: TRUE = virginica | PRED = virginica  --> CORRECT
# 36: TRUE = setosa | PRED = setosa  --> CORRECT
# 37: TRUE = setosa | PRED = setosa  --> CORRECT
# 38: TRUE = setosa | PRED = setosa  --> CORRECT
# 39: TRUE = versicolor | PRED = versicolor  --> CORRECT
# 40: TRUE = virginica | PRED = virginica  --> CORRECT
# 41: TRUE = virginica | PRED = virginica  --> CORRECT
# 42: TRUE = versicolor | PRED = versicolor  --> CORRECT
# 43: TRUE = setosa | PRED = setosa  --> CORRECT
# 44: TRUE = setosa | PRED = setosa  --> CORRECT
